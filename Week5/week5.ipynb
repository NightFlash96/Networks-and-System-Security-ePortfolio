# %% [markdown]
# # Week 5
# ### Web Security

# %%
# %pip install wapiti3
# Out:
# Requirement already satisfied: wapiti3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (3.2.10)
# Requirement already satisfied: aiosqlite<1.0,>=0.19 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (0.21.0)
# Requirement already satisfied: playwright<2.0,>=1.42 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (1.56.0)
# Requirement already satisfied: beautifulsoup4<5.0,>=4.12 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (4.12.3)
# Requirement already satisfied: browser-cookie3<0.21,>=0.19 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (0.20.1)
# Requirement already satisfied: dnspython<3.0,>=2.6 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (2.8.0)
# Requirement already satisfied: httpcore<2.0,>=1.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (1.0.9)
# Requirement already satisfied: httpx<1.0,>=0.27 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpx[brotli,socks]<1.0,>=0.27->wapiti3) (0.28.1)
# Requirement already satisfied: httpx-ntlm<2.0,>=1.4 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (1.4.0)
# Requirement already satisfied: mako<2.0,>=1.2 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (1.3.10)
# Requirement already satisfied: mitmproxy<13.0,>=12.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (12.2.1)
# Requirement already satisfied: packaging<26.0,>=23.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (24.2)
# Requirement already satisfied: sqlalchemy<3.0,>=2.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (2.0.44)
# Requirement already satisfied: tld<0.14,>=0.13 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (0.13.1)
# Requirement already satisfied: wapiti-swagger<0.2.0,>=0.1.9 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti3) (0.1.9)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from aiosqlite<1.0,>=0.19->wapiti3) (4.14.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4<5.0,>=4.12->wapiti3) (2.6)
# Requirement already satisfied: lz4 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from browser-cookie3<0.21,>=0.19->wapiti3) (4.4.5)
# Requirement already satisfied: pycryptodomex in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from browser-cookie3<0.21,>=0.19->wapiti3) (3.23.0)
# Requirement already satisfied: shadowcopy in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from browser-cookie3<0.21,>=0.19->wapiti3) (0.0.4)
# Requirement already satisfied: certifi in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpcore<2.0,>=1.0->wapiti3) (2024.12.14)
# Requirement already satisfied: h11>=0.16 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpcore<2.0,>=1.0->wapiti3) (0.16.0)
# Requirement already satisfied: anyio in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0,>=0.27->httpx[brotli,socks]<1.0,>=0.27->wapiti3) (4.12.0)
# Requirement already satisfied: idna in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0,>=0.27->httpx[brotli,socks]<1.0,>=0.27->wapiti3) (3.10)
# Requirement already satisfied: pyspnego>=0.3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpx-ntlm<2.0,>=1.4->wapiti3) (0.12.0)
# Requirement already satisfied: brotli in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpx[brotli,socks]<1.0,>=0.27->wapiti3) (1.2.0)
# Requirement already satisfied: socksio==1.* in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from httpx[brotli,socks]<1.0,>=0.27->wapiti3) (1.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mako<2.0,>=1.2->wapiti3) (3.0.3)
# Requirement already satisfied: aioquic<=1.2.0,>=1.2.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (1.2.0)
# Requirement already satisfied: argon2-cffi<=25.1.0,>=23.1.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (25.1.0)
# Requirement already satisfied: asgiref<=3.10.0,>=3.2.10 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (3.10.0)
# Requirement already satisfied: bcrypt<=5.0.0,>=5.0.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (5.0.0)
# Requirement already satisfied: cryptography<=46.1,>=42.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (46.0.3)
# Requirement already satisfied: flask<=3.1.2,>=3.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (3.1.2)
# Requirement already satisfied: h2<=4.3.0,>=4.3.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (4.3.0)
# Requirement already satisfied: hyperframe<=6.1.0,>=6.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (6.1.0)
# Requirement already satisfied: kaitaistruct<=0.11,>=0.10 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (0.11)
# Requirement already satisfied: ldap3<=2.9.1,>=2.8 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (2.9.1)
# Requirement already satisfied: mitmproxy-rs<0.13,>=0.12.6 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (0.12.8)
# Requirement already satisfied: msgpack<=1.1.2,>=1.0.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (1.1.2)
# Requirement already satisfied: pyOpenSSL<=25.3.0,>=24.3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (25.3.0)
# Requirement already satisfied: pyparsing<=3.2.5,>=2.4.2 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (3.2.1)
# Requirement already satisfied: pyperclip<=1.11.0,>=1.9.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (1.11.0)
# Requirement already satisfied: ruamel.yaml<=0.18.16,>=0.18.10 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (0.18.16)
# Requirement already satisfied: sortedcontainers<=2.4.0,>=2.3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (2.4.0)
# Requirement already satisfied: tornado<=6.5.2,>=6.5.0 in c:\users\nightflash96\appdata\roaming\python\python312\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (6.5.2)
# Requirement already satisfied: urwid<=3.0.3,>=2.6.14 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (3.0.3)
# Requirement already satisfied: wsproto<=1.2.0,>=1.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (1.2.0)
# Requirement already satisfied: publicsuffix2<=2.20191221,>=2.20190812 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (2.20191221)
# Requirement already satisfied: zstandard<=0.25.0,>=0.25 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (0.25.0)
# Requirement already satisfied: pydivert<=2.1.0,>=2.0.3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy<13.0,>=12.0->wapiti3) (2.1.0)
# Requirement already satisfied: pylsqpack<0.4.0,>=0.3.3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from aioquic<=1.2.0,>=1.2.0->mitmproxy<13.0,>=12.0->wapiti3) (0.3.23)
# Requirement already satisfied: service-identity>=24.1.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from aioquic<=1.2.0,>=1.2.0->mitmproxy<13.0,>=12.0->wapiti3) (24.2.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi<=25.1.0,>=23.1.0->mitmproxy<13.0,>=12.0->wapiti3) (25.1.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from cryptography<=46.1,>=42.0->mitmproxy<13.0,>=12.0->wapiti3) (2.0.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from flask<=3.1.2,>=3.0->mitmproxy<13.0,>=12.0->wapiti3) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from flask<=3.1.2,>=3.0->mitmproxy<13.0,>=12.0->wapiti3) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from flask<=3.1.2,>=3.0->mitmproxy<13.0,>=12.0->wapiti3) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from flask<=3.1.2,>=3.0->mitmproxy<13.0,>=12.0->wapiti3) (3.1.6)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from flask<=3.1.2,>=3.0->mitmproxy<13.0,>=12.0->wapiti3) (3.1.4)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from h2<=4.3.0,>=4.3.0->mitmproxy<13.0,>=12.0->wapiti3) (4.1.0)
# Requirement already satisfied: pyasn1>=0.4.6 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from ldap3<=2.9.1,>=2.8->mitmproxy<13.0,>=12.0->wapiti3) (0.6.1)
# Requirement already satisfied: mitmproxy-windows==0.12.8 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from mitmproxy-rs<0.13,>=0.12.6->mitmproxy<13.0,>=12.0->wapiti3) (0.12.8)
# Requirement already satisfied: pyee<14,>=13 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from playwright<2.0,>=1.42->wapiti3) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from playwright<2.0,>=1.42->wapiti3) (3.3.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from ruamel.yaml<=0.18.16,>=0.18.10->mitmproxy<13.0,>=12.0->wapiti3) (0.2.15)
# Requirement already satisfied: wcwidth in c:\users\nightflash96\appdata\roaming\python\python312\site-packages (from urwid<=3.0.3,>=2.6.14->mitmproxy<13.0,>=12.0->wapiti3) (0.2.14)
# Requirement already satisfied: PyYAML>=6.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from wapiti-swagger<0.2.0,>=0.1.9->wapiti3) (6.0.3)
# Requirement already satisfied: pycparser in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography<=46.1,>=42.0->mitmproxy<13.0,>=12.0->wapiti3) (2.23)
# Requirement already satisfied: colorama in c:\users\nightflash96\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask<=3.1.2,>=3.0->mitmproxy<13.0,>=12.0->wapiti3) (0.4.6)
# Requirement already satisfied: sspilib>=0.3.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from pyspnego>=0.3->httpx-ntlm<2.0,>=1.4->wapiti3) (0.5.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from service-identity>=24.1.0->aioquic<=1.2.0,>=1.2.0->mitmproxy<13.0,>=12.0->wapiti3) (25.4.0)
# Requirement already satisfied: pyasn1-modules in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from service-identity>=24.1.0->aioquic<=1.2.0,>=1.2.0->mitmproxy<13.0,>=12.0->wapiti3) (0.4.2)
# Requirement already satisfied: wmi in c:\users\nightflash96\appdata\local\programs\python\python312\lib\site-packages (from shadowcopy->browser-cookie3<0.21,>=0.19->wapiti3) (1.5.1)
# Requirement already satisfied: pywin32 in c:\users\nightflash96\appdata\roaming\python\python312\site-packages (from wmi->shadowcopy->browser-cookie3<0.21,>=0.19->wapiti3) (311)
# Note: you may need to restart the kernel to use updated packages.
# 'wapiti' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
from IPython.display import display, HTML
import glob
import pathlib

# Base 'out' name you passed to Wapiti (-o). Update if you used a different name.

out_name = "juice_wapiti_report.html"

def find_html_report(out):
    # If out is a file and ends with .html, use it
    if os.path.isfile(out) and out.lower().endswith('.html'):
        return os.path.abspath(out)
    # If out is a directory, search for the newest .html inside it
    if os.path.isdir(out):
        matches = glob.glob(os.path.join(out, "*.html"))
        if matches:
            # choose the most recent file
            matches.sort(key=os.path.getmtime, reverse=True)
            return os.path.abspath(matches[0])
    # If out doesn't exist as provided, search for any html file pattern that
    # looks like wapiti output
    candidates = glob.glob(out + "*/*.html") + glob.glob(out + "*.html")
    if candidates:
        candidates.sort(key=os.path.getmtime, reverse=True)
        return os.path.abspath(candidates[0])
    return None

report_path = find_html_report(out_name)

if report_path:
    print("Report file found:", report_path)
    try:
        with open(report_path, 'r', encoding='utf-8') as f:
            html = f.read()
        display(HTML(html))
    except Exception as e:
        print("Could not render HTML inline (error):", e)
        print("Open the file in your browser instead:", report_path)
else:
    print("No HTML report found. Check that the scan produced the report and "
          "that 'out_name' matches the -o argument passed to Wapiti.")
# Out:
# Report file found: c:\Users\NightFlash96\Desktop\Code\Y3 S1\Networks-and-System-Security-ePortfolio\Week5\juice_wapiti_report.html\report.html
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Wapiti scan report</title>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<link rel="stylesheet" type="text/css" href="css/kube.min.css" />
#     <link rel="stylesheet" type="text/css" href="css/master.css" />
# </head>
# <body>
#     <div id="page">
#         <header style="text-align: center">
#         <h2 class="title" style="text-align: center">Wapiti vulnerability report</h2>
#         <h3>Target: ${target}</h3>
#         <p>Date of the scan: ${scan_date}. Scope of the scan: ${scan_scope}. Crawled pages: ${crawled_pages_nbr}</p>
#         </header>
#         <hr />
#         % if auth_dict != None:
#         <h4>Authentication</h4>
#         <p>
#             Url: ${auth_dict["url"]}<br>
#             Logged in: ${auth_dict["logged_in"]}<br>
#             % if auth_form_dict != None and len(auth_form_dict) > 0:
#             Login field: ${auth_form_dict["login_field"]}<br>
#             Password field: ${auth_form_dict["password_field"]}<br>
#             % endif
#         </p>
#         <hr />
#         % endif
#
#         <h4>Summary</h4>
#         <table class="width-100 hovered" style="background: url('logo_clear.png') no-repeat center;">
#             <thead>
#                 <tr>
#                     <th>Category</th>
#                     <th>Number of vulnerabilities found</th>
#                 </tr>
#             </thead>
#             <tbody id="summary">
#                 % for i, vuln_name in enumerate(vulnerabilities):
#                     <tr>
#                         <td class="small">
#                             % if len(vulnerabilities[vuln_name]):
#                             <a href="#vuln_type_${i}">${vuln_name}</a>
#                             % else:
#                             ${vuln_name}
#                             % endif
#                         </td>
#                         <td class="small .text-centered">${len(vulnerabilities[vuln_name])}</td>
#                     </tr>
#                 % endfor
#                 % for i, anomaly_name in enumerate(anomalies):
#                     <tr>
#                         <td class="small">
#                             % if len(anomalies[anomaly_name]):
#                             <a href="#anom_type_${i}">${anomaly_name}</a>
#                             % else:
#                             ${anomaly_name}
#                             % endif
#                         </td>
#                         <td class="small .text-centered">${len(anomalies[anomaly_name])}</td>
#                     </tr>
#                 % endfor
#                 % for i, additional_name in enumerate(additionals):
#                     <tr>
#                         <td class="small">
#                             % if len(additionals[additional_name]):
#                             <a href="#addition_type_${i}">${additional_name}</a>
#                             % else:
#                             ${additional_name}
#                             % endif
#                         </td>
#                         <td class="small .text-centered">${len(additionals[additional_name])}</td>
#                     </tr>
#                 % endfor
#             </tbody>
#         </table>
#         <hr />
#         <div id="details">
#             % for i, vuln_name in enumerate(vulnerabilities):
#                 % if len(vulnerabilities[vuln_name]):
#                 <h3 id="vuln_type_${i}">${vuln_name}</h3>
#                 <dl>
#                     <dt>Description</dt>
#                     <dd>${flaws[vuln_name]["desc"] | h}</dd>
#                 </dl>
#
#                     % for j, vulnerability in enumerate(vulnerabilities[vuln_name]):
#                         <h4>${level_to_emoji(vulnerability["level"])} Vulnerability found in ${vulnerability["path"] | h}</h4>
#                         <nav class="tabs" data-kube="tabs" data-equal="true" data-height="equal">
#                             <a href="#tab-vuln-${i}-${j}-1" class="is-active">Description</a>
#                             <a href="#tab-vuln-${i}-${j}-2">HTTP Request</a>
#                             % if detailed_report is True and vulnerability["detail"]["response"] is not None:
#                                 <a href="#tab-vuln-${i}-${j}-3">HTTP Response</a>
#                             % endif
#                             <a href="#tab-vuln-${i}-${j}-4">cURL command line</a>
#                             <a href="#tab-vuln-${i}-${j}-5">WSTG Code</a>
#                         </nav>
#                         <section id="tab-vuln-${i}-${j}-1" style="min-height: 124px;">
#                             <pre>${vulnerability["info"] | h}</pre>
#                         </section>
#                         <section id="tab-vuln-${i}-${j}-2" style="min-height: 124px;" class="is-hidden">
#                             <pre style="white-space: normal;">
#                                 % for line in vulnerability["http_request"].split("\n"):
#                                     ${line | h}
#                                     <br>
#                                 % endfor
#                             </pre>
#                         </section>
#                         % if detailed_report is True and vulnerability["detail"]["response"] is not None:
#                             <section id="tab-vuln-${i}-${j}-3" style="min-height: 124px;" class="is-hidden">
#                                 <pre style="white-space: nowrap">
#                                     HTTP ${vulnerability["detail"]["response"]["status_code"] | h}<br />
#                                     % if vulnerability["detail"]["response"]["headers"] is not None:
#                                         % for header in vulnerability["detail"]["response"]["headers"]:
#                                             ${header[0] | h}: ${header[1] | h}<br />
#                                         %endfor
#                                     %endif
#                                     <br />
#                                     ${vulnerability["detail"]["response"]["body"] | h}
#                                 </pre>
#                             </section>
#                         % endif
#                         <section id="tab-vuln-${i}-${j}-4" style="min-height: 124px;" class="is-hidden">
#                             <pre>${vulnerability["curl_command"] | h}</pre>
#                         </section>
#                         <section id="tab-vuln-${i}-${j}-5" style="min-height: 124px;" class="is-hidden">
#                             <pre>${vulnerability["wstg"] | h}</pre>
#                         </section>
#                     % endfor
#
#                 <dl><dt>Solutions</dt><dd>${flaws[vuln_name]["sol"]}</dd></dl>
#                 <h5>References</h5>
#                 <ul>
#                     % for ref_name, ref_url in flaws[vuln_name]["ref"].items():
#                     <li><a href="${ref_url}">${ref_name | h}</a></li>
#                     % endfor
#                 </ul>
#                 <br />
#                 <hr>
#                 % endif
#             % endfor
#             % for i, anomaly_name in enumerate(anomalies):
#                 % if len(anomalies[anomaly_name]):
#                 <h3 id="anom_type_${i}">${anomaly_name}</h3>
#                 <dl>
#                     <dt>Description</dt>
#                     <dd>${flaws[anomaly_name]["desc"] | h}</dd>
#                 </dl>
#
#                     % for j, anomaly in enumerate(anomalies[anomaly_name]):
#                         <h4>🤕 Anomaly found in ${anomaly["path"] | h}</h4>
#                         <nav class="tabs" data-kube="tabs" data-equal="true" data-height="equal">
#                             <a href="#tab-anom-${i}-${j}-1" class="is-active">Description</a>
#                             <a href="#tab-anom-${i}-${j}-2">HTTP Request</a>
#                             % if detailed_report is True and anomaly["detail"]["response"] is not None:
#                                 <a href="#tab-anom-${i}-${j}-3">HTTP Response</a>
#                             % endif
#                             <a href="#tab-anom-${i}-${j}-4">cURL command line</a>
